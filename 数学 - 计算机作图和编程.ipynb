# %%
from sympy import *

# %%
from sympy.plotting import plot3d

# %%
 x, y = symbols('x y')

# %%
plot3d(x*y, (x, -5, 5), (y, -5, 5))

# %%
init_printing()

# %%
# %matplotlib inline

# %%
plot3d(x+y,x-y,(x, -5, 5), (y, -5, 5))

# %%
u = symbols('u')

# %%
from sympy.plotting import plot_parametric

# %%
plot_parametric(cos(u),sin(u),(u,-5,5))

# %%
plot(x+5,-1*x)

# %%
f = symbols('f')
f = 1/(x+1) - 3/(3*x+4)
f
# Out:
#      3        1
# - ─────── + ─────
#   3⋅x + 4   x + 1

# %%
f = x**5 +10*x**4+35*x**3+50*x+24
g =factor(f)
g
# Out:
#  5       4       3
# x  + 10⋅x  + 35⋅x  + 50⋅x + 24

# %%
factor(x**2 + 3*x +2)
# Out:
# (x + 1)⋅(x + 2)

# %%
factor(x**2 + 3*x +1)
# Out:
#  2
# x  + 3⋅x + 1

# %%
expand((x+1)**2)
# Out:
#  2
# x  + 2⋅x + 1

# %%
simplify( sin(x)**2 + cos(x)**2)
# Out:
# 1

# %%
cancel(1/x + (3*x/2 - 2)/(x - 4))
# Out:
#    2
# 3⋅x  - 2⋅x - 8
# ──────────────
#      2
#   2⋅x  - 8⋅x
